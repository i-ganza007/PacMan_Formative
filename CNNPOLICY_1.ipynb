# %% [markdown]
# <a href="https://colab.research.google.com/github/i-ganza007/PacMan_Formative/blob/main/CNNPOLICY_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y gymnasium stable-baselines3 ale-py shimmy tensorboard protobuf -y
# !rm -rf /usr/local/lib/python3.11/dist-packages/gymnasium*
# !rm -rf ~/.cache/pip
# !pip cache purge

# !pip install --no-cache-dir \
    "protobuf==3.20.3" \
    "tensorboard==2.14.0" \
    "gymnasium[atari,accept-rom-license]==0.29.1" \
    "ale-py==0.8.1" \
    "shimmy==0.2.1" \
    "stable-baselines3==2.3.0" \
    "autorom[accept-rom-license]"

# !python -c "import gymnasium.vector; print(dir(gymnasium.vector))"

# %%
import os
import gc
import torch
import warnings
import numpy as np
import gymnasium as gym
import ale_py
from datetime import datetime
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
warnings.filterwarnings('ignore')
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback, CallbackList
from gymnasium.wrappers import GrayScaleObservation, ResizeObservation, TransformReward

torch.cuda.empty_cache()
gc.collect()

CONFIG_ID = 1
configs = [
    {"lr": 2e-4, "gamma": 0.999, "batch": 32,
     "epsilon_start": 1.0, "epsilon_end": 0.05, "epsilon_decay": 0.3,
     "buffer": 20_000, "img_size": 64, "stack": 1, "net_arch": [128, 128]},

    {"lr": 1e-4, "gamma": 0.99, "batch": 32,
     "epsilon_start": 1.0, "epsilon_end": 0.02, "epsilon_decay": 0.25,
     "buffer": 20_000, "img_size": 64, "stack": 1, "net_arch": [128, 128]},

    {"lr": 3e-4, "gamma": 0.999, "batch": 64,
     "epsilon_start": 1.0, "epsilon_end": 0.1, "epsilon_decay": 0.2,
     "buffer": 25_000, "img_size": 64, "stack": 1, "net_arch": [128, 128]},

    {"lr": 2e-4, "gamma": 0.95, "batch": 16,
     "epsilon_start": 1.0, "epsilon_end": 0.01, "epsilon_decay": 0.4,
     "buffer": 15_000, "img_size": 64, "stack": 1, "net_arch": [64, 64]},

    {"lr": 1.5e-4, "gamma": 0.995, "batch": 32,
     "epsilon_start": 1.0, "epsilon_end": 0.05, "epsilon_decay": 0.25,
     "buffer": 20_000, "img_size": 64, "stack": 1, "net_arch": [128, 128]},
]

cfg = configs[CONFIG_ID - 1]

# %%
print(f" PACMAN DQN TRAINING - CONFIG {CONFIG_ID}")

for k, v in cfg.items():
    if k == "epsilon_decay":
        print(f"{k:18}: {v:.1%} of timesteps")
    elif k == "net_arch":
        print(f"{k:18}: {v}")
    else:
        print(f"{k:18}: {v}")
print(f"{'GPU':18}: {torch.cuda.get_device_name(0)}")
print(f"{'VRAM Total':18}: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
#  PACMAN DQN TRAINING - CONFIG 1
# lr                : 0.0002
# gamma             : 0.999
# batch             : 32
# epsilon_start     : 1.0
# epsilon_end       : 0.05
# epsilon_decay     : 30.0% of timesteps
# buffer            : 20000
# img_size          : 64
# stack             : 1
# net_arch          : [128, 128]
# GPU               : Tesla P100-PCIE-16GB
# VRAM Total        : 17.1 GB

# %%
def make_base_env(render_mode=None):
    env = gym.make("ALE/Pacman-v5", frameskip=4, render_mode=render_mode)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, (cfg["img_size"], cfg["img_size"]))
    env = TransformReward(env, lambda r: np.clip(r, -1.0, 1.0))
    return env

train_raw = make_base_env()
train_raw = Monitor(train_raw, filename=f"./logs/episode_logs/cfg{CONFIG_ID}.monitor.csv", allow_early_resets=True)
train_env = DummyVecEnv([lambda: train_raw])
if cfg["stack"] > 1:
    train_env = VecFrameStack(train_env, n_stack=cfg["stack"])

eval_raw = make_base_env()
eval_env = DummyVecEnv([lambda: eval_raw])
if cfg["stack"] > 1:
    eval_env = VecFrameStack(eval_env, n_stack=cfg["stack"])
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
model = DQN(
    "MlpPolicy",
    train_env,
    learning_rate=cfg["lr"],
    gamma=cfg["gamma"],
    batch_size=cfg["batch"],
    buffer_size=cfg["buffer"],
    learning_starts=5_000,
    target_update_interval=1_000,
    train_freq=4,
    gradient_steps=1,
    exploration_initial_eps=cfg["epsilon_start"],
    exploration_final_eps=cfg["epsilon_end"],
    exploration_fraction=cfg["epsilon_decay"],
    policy_kwargs=dict(net_arch=cfg["net_arch"]),
    tensorboard_log="./logs/tensorboard/",
    device="cuda",
    verbose=1
)

print(f"Initial VRAM Usage: {torch.cuda.memory_allocated() / 1e9:.2f} GB\n")
# Out:
# Using cuda device
# Initial VRAM Usage: 0.00 GB

# %%
class MemoryCallback(BaseCallback):
    def __init__(self, check_freq=10_000):
        super().__init__()
        self.check_freq = check_freq
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            alloc = torch.cuda.memory_allocated() / 1e9
            reserved = torch.cuda.memory_reserved() / 1e9
            peak = torch.cuda.max_memory_allocated() / 1e9
            print(f"Step {self.n_calls:,} | VRAM: {alloc:.2f}G alloc | {reserved:.2f}G res | {peak:.2f}G peak")
        return True

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=f"./logs/best_models/cfg{CONFIG_ID}/",
    log_path=f"./logs/eval_logs/cfg{CONFIG_ID}/",
    eval_freq=10_000,
    n_eval_episodes=5,
    deterministic=False,
    render=False,
    verbose=1
)

callback = CallbackList([MemoryCallback(check_freq=10_000), eval_callback])

total_timesteps = 1_500_000
print(f"Starting training for {total_timesteps:,} timesteps...")
print(" Logs:")
print(f" • Episode CSV → ./logs/episode_logs/cfg{CONFIG_ID}.monitor.csv")
print(f" • TensorBoard → tensorboard --logdir ./logs/tensorboard/")
print(f" • Eval Results → ./logs/eval_logs/cfg{CONFIG_ID}/")
print(f" • Best Model → ./logs/best_models/cfg{CONFIG_ID}/\n")

model.learn(
    total_timesteps=total_timesteps,
    tb_log_name=f"cfg{CONFIG_ID}_p100",
    log_interval=1,
    callback=callback,
    progress_bar=True,
    reset_num_timesteps=True
)

print("\nEvaluating final policy...")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=15, deterministic=False)  # ← FIXED

model.save(f"dqn_pacman_p100_cfg{CONFIG_ID}")
peak_vram = torch.cuda.max_memory_allocated() / 1e9

print(" TRAINING COMPLETE")
print(f" Config ID : {CONFIG_ID}")
print(f" Mean Reward : {mean_reward:.1f} ± {std_reward:.1f}")
print(f" Peak VRAM : {peak_vram:.2f} GB")
print(f" Model Saved : dqn_pacman_p100_cfg{CONFIG_ID}.zip")
print(f" TensorBoard : tensorboard --logdir ./logs/tensorboard/")

print("\nStarting LIVE RENDER – Close window to stop...")
render_env = make_base_env(render_mode="human")
obs, _ = render_env.reset()
for _ in range(2000):
    action, _ = model.predict(obs, deterministic=False)
    obs, reward, terminated, truncated, info = render_env.step(action)
    render_env.render()
    if terminated or truncated:
        obs, _ = render_env.reset()
render_env.close()

torch.cuda.empty_cache()
gc.collect()
train_env.close()
eval_env.close()
print("\nCleanup complete. Ready for next run!\n")
# Out:
# Starting training for 1,500,000 timesteps...
#  Logs:
#  • Episode CSV → ./logs/episode_logs/cfg1.monitor.csv
#  • TensorBoard → tensorboard --logdir ./logs/tensorboard/
#  • Eval Results → ./logs/eval_logs/cfg1/
#  • Best Model → ./logs/best_models/cfg1/
#
# Logging to ./logs/tensorboard/cfg1_p100_2
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | 7        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1        |
# |    fps              | 685      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 300      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 2        |
# |    fps              | 879      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 898      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 411      |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 3        |
# |    fps              | 864      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1232     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 407      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 900      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 397      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 5        |
# |    fps              | 922      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 400      |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 6        |
# |    fps              | 940      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 412      |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 7        |
# |    fps              | 957      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 418      |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 971      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 411      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 9        |
# |    fps              | 976      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 406      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 982      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 11       |
# |    fps              | 986      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 900      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5060     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 2        |
# |    n_updates        | 14       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 13       |
# |    fps              | 866      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5484     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.606    |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 14       |
# |    fps              | 841      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5874     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.349    |
# |    n_updates        | 218      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 426      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 15       |
# |    fps              | 817      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6390     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.355    |
# |    n_updates        | 347      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 801      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6780     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.204    |
# |    n_updates        | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 17       |
# |    fps              | 789      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 7138     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.275    |
# |    n_updates        | 534      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 18       |
# |    fps              | 775      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 7618     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.215    |
# |    n_updates        | 654      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 428      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 19       |
# |    fps              | 761      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8140     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0399   |
# |    n_updates        | 784      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 747      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8708     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.584    |
# |    n_updates        | 926      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 21       |
# |    fps              | 740      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 9092     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.395    |
# |    n_updates        | 1022     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 22       |
# |    fps              | 733      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 9498     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.583    |
# |    n_updates        | 1124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 23       |
# |    fps              | 728      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 9874     |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0892   |
# |    n_updates        | 1218     |
# ----------------------------------
# Step 10,000 | VRAM: 0.03G alloc | 0.05G res | 0.03G peak
# Eval num_timesteps=10000, episode_reward=18.80 +/- 6.24
# Episode length: 449.20 +/- 61.05
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 449      |
# |    mean_reward      | 18.8     |
# | rollout/            |          |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    total_timesteps  | 10000    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.172    |
# |    n_updates        | 1249     |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 628      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 10254    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.115    |
# |    n_updates        | 1313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 25       |
# |    fps              | 627      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 10928    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.029    |
# |    n_updates        | 1481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 439      |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 26       |
# |    fps              | 626      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 11416    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.425    |
# |    n_updates        | 1603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 27       |
# |    fps              | 626      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 11892    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0879   |
# |    n_updates        | 1722     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 439      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 625      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 12302    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.189    |
# |    n_updates        | 1825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 29       |
# |    fps              | 624      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 12766    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0774   |
# |    n_updates        | 1941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 623      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 13130    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0539   |
# |    n_updates        | 2032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 31       |
# |    fps              | 622      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 13486    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.434    |
# |    n_updates        | 2121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 622      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 13844    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.416    |
# |    n_updates        | 2210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 33       |
# |    fps              | 621      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 14278    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0589   |
# |    n_updates        | 2319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 34       |
# |    fps              | 620      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 14638    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.291    |
# |    n_updates        | 2409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 35       |
# |    fps              | 620      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 15044    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0359   |
# |    n_updates        | 2510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 619      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 15460    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0423   |
# |    n_updates        | 2614     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 37       |
# |    fps              | 618      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15878    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0366   |
# |    n_updates        | 2719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 38       |
# |    fps              | 618      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 16232    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0164   |
# |    n_updates        | 2807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 39       |
# |    fps              | 618      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 16662    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0684   |
# |    n_updates        | 2915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 428      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 617      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 17132    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0256   |
# |    n_updates        | 3032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 428      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 41       |
# |    fps              | 616      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 17542    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0341   |
# |    n_updates        | 3135     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 42       |
# |    fps              | 616      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 17934    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0673   |
# |    n_updates        | 3233     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 43       |
# |    fps              | 616      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 18362    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0323   |
# |    n_updates        | 3340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 426      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 615      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 18736    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.066    |
# |    n_updates        | 3433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 45       |
# |    fps              | 615      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 19118    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0522   |
# |    n_updates        | 3529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 46       |
# |    fps              | 614      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 19744    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0289   |
# |    n_updates        | 3685     |
# ----------------------------------
# Step 20,000 | VRAM: 0.03G alloc | 0.05G res | 0.03G peak
# Eval num_timesteps=20000, episode_reward=15.00 +/- 2.19
# Episode length: 442.40 +/- 47.76
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 442      |
# |    mean_reward      | 15       |
# | rollout/            |          |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0385   |
# |    n_updates        | 3749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 47       |
# |    fps              | 578      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 20226    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0154   |
# |    n_updates        | 3806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 578      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 20656    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.109    |
# |    n_updates        | 3913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 49       |
# |    fps              | 579      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 21094    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0638   |
# |    n_updates        | 4023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 50       |
# |    fps              | 579      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 21506    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0404   |
# |    n_updates        | 4126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 51       |
# |    fps              | 580      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 21862    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0353   |
# |    n_updates        | 4215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 581      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 22614    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.156    |
# |    n_updates        | 4403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 53       |
# |    fps              | 581      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 22960    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.012    |
# |    n_updates        | 4489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 54       |
# |    fps              | 581      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 23326    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0213   |
# |    n_updates        | 4581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 55       |
# |    fps              | 582      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 23738    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0354   |
# |    n_updates        | 4684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 582      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 24368    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0197   |
# |    n_updates        | 4841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 57       |
# |    fps              | 582      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 24706    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0184   |
# |    n_updates        | 4926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 58       |
# |    fps              | 583      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 25280    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0309   |
# |    n_updates        | 5069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 59       |
# |    fps              | 583      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 25632    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0471   |
# |    n_updates        | 5157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 584      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 26056    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0556   |
# |    n_updates        | 5263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 61       |
# |    fps              | 584      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 26526    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0742   |
# |    n_updates        | 5381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 62       |
# |    fps              | 584      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 26932    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0525   |
# |    n_updates        | 5482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 63       |
# |    fps              | 585      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 27306    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0185   |
# |    n_updates        | 5576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 585      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 27916    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0331   |
# |    n_updates        | 5728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 65       |
# |    fps              | 586      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 28424    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.483    |
# |    n_updates        | 5855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 66       |
# |    fps              | 586      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 28886    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0141   |
# |    n_updates        | 5971     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 67       |
# |    fps              | 586      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 29206    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.05     |
# |    n_updates        | 6051     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 586      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 29720    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.482    |
# |    n_updates        | 6179     |
# ----------------------------------
# Step 30,000 | VRAM: 0.03G alloc | 0.05G res | 0.03G peak
# Eval num_timesteps=30000, episode_reward=15.20 +/- 6.24
# Episode length: 470.80 +/- 114.73
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 471      |
# |    mean_reward      | 15.2     |
# | rollout/            |          |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    total_timesteps  | 30000    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0435   |
# |    n_updates        | 6249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 69       |
# |    fps              | 561      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 30120    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0149   |
# |    n_updates        | 6279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 70       |
# |    fps              | 561      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 30604    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0192   |
# |    n_updates        | 6400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 71       |
# |    fps              | 561      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 31002    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.032    |
# |    n_updates        | 6500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 562      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 31504    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0169   |
# |    n_updates        | 6625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 73       |
# |    fps              | 562      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 31902    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0392   |
# |    n_updates        | 6725     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 74       |
# |    fps              | 563      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 32424    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0061   |
# |    n_updates        | 6855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 75       |
# |    fps              | 563      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 32784    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0568   |
# |    n_updates        | 6945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 563      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 33200    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0101   |
# |    n_updates        | 7049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 77       |
# |    fps              | 564      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 33612    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0222   |
# |    n_updates        | 7152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 78       |
# |    fps              | 564      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 33936    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0253   |
# |    n_updates        | 7233     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 79       |
# |    fps              | 564      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 34458    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0824   |
# |    n_updates        | 7364     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 564      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 34840    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.024    |
# |    n_updates        | 7459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 81       |
# |    fps              | 565      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 35162    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.527    |
# |    n_updates        | 7540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 82       |
# |    fps              | 565      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 35522    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0618   |
# |    n_updates        | 7630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 83       |
# |    fps              | 565      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 35934    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.158    |
# |    n_updates        | 7733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 566      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 36300    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0529   |
# |    n_updates        | 7824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 85       |
# |    fps              | 566      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 36716    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.209    |
# |    n_updates        | 7928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 86       |
# |    fps              | 566      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 37192    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0333   |
# |    n_updates        | 8047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 87       |
# |    fps              | 566      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 37526    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.066    |
# |    n_updates        | 8131     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 566      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 38100    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0461   |
# |    n_updates        | 8274     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 89       |
# |    fps              | 567      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 38494    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0525   |
# |    n_updates        | 8373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 90       |
# |    fps              | 567      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 38832    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0491   |
# |    n_updates        | 8457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 14.2     |
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 439      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3434     |
# |    fps              | 421      |
# |    time_elapsed     | 3533     |
# |    total_timesteps  | 1489946  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.105    |
# |    n_updates        | 371236   |
# ----------------------------------
# Step 1,490,000 | VRAM: 0.03G alloc | 0.05G res | 0.03G peak
# Eval num_timesteps=1490000, episode_reward=6.80 +/- 3.87
# Episode length: 422.80 +/- 18.53
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 423      |
# |    mean_reward      | 6.8      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 1490000  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.093    |
# |    n_updates        | 371249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3435     |
# |    fps              | 421      |
# |    time_elapsed     | 3536     |
# |    total_timesteps  | 1490376  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0463   |
# |    n_updates        | 371343   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3436     |
# |    fps              | 421      |
# |    time_elapsed     | 3537     |
# |    total_timesteps  | 1490756  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0262   |
# |    n_updates        | 371438   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3437     |
# |    fps              | 421      |
# |    time_elapsed     | 3538     |
# |    total_timesteps  | 1491148  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 1.06     |
# |    n_updates        | 371536   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3438     |
# |    fps              | 421      |
# |    time_elapsed     | 3539     |
# |    total_timesteps  | 1491504  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.228    |
# |    n_updates        | 371625   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3439     |
# |    fps              | 421      |
# |    time_elapsed     | 3540     |
# |    total_timesteps  | 1492128  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.103    |
# |    n_updates        | 371781   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3440     |
# |    fps              | 421      |
# |    time_elapsed     | 3541     |
# |    total_timesteps  | 1492516  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 4.29     |
# |    n_updates        | 371878   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3441     |
# |    fps              | 421      |
# |    time_elapsed     | 3542     |
# |    total_timesteps  | 1492860  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.597    |
# |    n_updates        | 371964   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3442     |
# |    fps              | 421      |
# |    time_elapsed     | 3542     |
# |    total_timesteps  | 1493230  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.147    |
# |    n_updates        | 372057   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3443     |
# |    fps              | 421      |
# |    time_elapsed     | 3543     |
# |    total_timesteps  | 1493600  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.452    |
# |    n_updates        | 372149   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3444     |
# |    fps              | 421      |
# |    time_elapsed     | 3544     |
# |    total_timesteps  | 1494028  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.41     |
# |    n_updates        | 372256   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3445     |
# |    fps              | 421      |
# |    time_elapsed     | 3545     |
# |    total_timesteps  | 1494424  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0546   |
# |    n_updates        | 372355   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3446     |
# |    fps              | 421      |
# |    time_elapsed     | 3546     |
# |    total_timesteps  | 1494820  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.442    |
# |    n_updates        | 372454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3447     |
# |    fps              | 421      |
# |    time_elapsed     | 3547     |
# |    total_timesteps  | 1495206  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.199    |
# |    n_updates        | 372551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3448     |
# |    fps              | 421      |
# |    time_elapsed     | 3547     |
# |    total_timesteps  | 1495644  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0477   |
# |    n_updates        | 372660   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3449     |
# |    fps              | 421      |
# |    time_elapsed     | 3549     |
# |    total_timesteps  | 1496484  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0947   |
# |    n_updates        | 372870   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3450     |
# |    fps              | 421      |
# |    time_elapsed     | 3550     |
# |    total_timesteps  | 1496834  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.113    |
# |    n_updates        | 372958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3451     |
# |    fps              | 421      |
# |    time_elapsed     | 3551     |
# |    total_timesteps  | 1497318  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0308   |
# |    n_updates        | 373079   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3452     |
# |    fps              | 421      |
# |    time_elapsed     | 3552     |
# |    total_timesteps  | 1497648  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.154    |
# |    n_updates        | 373161   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3453     |
# |    fps              | 421      |
# |    time_elapsed     | 3552     |
# |    total_timesteps  | 1498044  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 1.08     |
# |    n_updates        | 373260   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3454     |
# |    fps              | 421      |
# |    time_elapsed     | 3553     |
# |    total_timesteps  | 1498492  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.103    |
# |    n_updates        | 373372   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3455     |
# |    fps              | 421      |
# |    time_elapsed     | 3555     |
# |    total_timesteps  | 1499036  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 5.44     |
# |    n_updates        | 373508   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3456     |
# |    fps              | 421      |
# |    time_elapsed     | 3555     |
# |    total_timesteps  | 1499418  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.127    |
# |    n_updates        | 373604   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 431      |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3457     |
# |    fps              | 421      |
# |    time_elapsed     | 3556     |
# |    total_timesteps  | 1499786  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.991    |
# |    n_updates        | 373696   |
# ----------------------------------
# Step 1,500,000 | VRAM: 0.03G alloc | 0.05G res | 0.03G peak
# Eval num_timesteps=1500000, episode_reward=7.00 +/- 3.74
# Episode length: 461.60 +/- 58.29
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 462      |
# |    mean_reward      | 7        |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 1500000  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 1.11     |
# |    n_updates        | 373749   |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Evaluating final policy...
#  TRAINING COMPLETE
#  Config ID : 1
#  Mean Reward : 9.0 ± 4.5
#  Peak VRAM : 0.03 GB
#  Model Saved : dqn_pacman_p100_cfg1.zip
#  TensorBoard : tensorboard --logdir ./logs/tensorboard/
#
# Starting LIVE RENDER – Close window to stop...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_259/2061341579.py in <cell line: 0>()
#      55
#      56 print("\nStarting LIVE RENDER – Close window to stop...")
# ---> 57 render_env = make_base_env(render_mode="human")
#      58 obs, _ = render_env.reset()
#      59 for _ in range(2000):
#
# /tmp/ipykernel_259/2710137608.py in make_base_env(render_mode)
#       1 def make_base_env(render_mode=None):
# ----> 2     env = gym.make("ALE/Pacman-v5", frameskip=4, render_mode=render_mode)
#       3     env = GrayScaleObservation(env)
#       4     env = ResizeObservation(env, (cfg["img_size"], cfg["img_size"]))
#       5     env = TransformReward(env, lambda r: np.clip(r, -1.0, 1.0))
#
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     800
#     801     try:
# --> 802         env = env_creator(**env_spec_kwargs)
#     803     except TypeError as e:
#     804         if (
#
# /usr/local/lib/python3.11/dist-packages/shimmy/atari_env.py in __init__(self, game, mode, difficulty, obs_type, frameskip, repeat_action_probability, full_action_space, max_num_frames_per_episode, render_mode)
#     169
#     170         # Seed + Load
# --> 171         self.seed()
#     172
#     173         if full_action_space:
#
# /usr/local/lib/python3.11/dist-packages/shimmy/atari_env.py in seed(self, seed)
#     223                 "https://github.com/mgbellemare/Arcade-Learning-Environment#rom-management"
#     224             )
# --> 225         self.ale.loadROM(getattr(roms, self._game))
#     226
#     227         if self._game_mode is not None:
#
# RuntimeError: Failed to initialize SDL
